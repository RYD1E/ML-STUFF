# %% [markdown]
# # Web Scraping Tutorial: Scraping ICC Cricket Website
#
#
# <img src="https://d1vd9vlqo1765y.cloudfront.net/blog/virat-kohli-to-miss-world-cup-warm-up-match-vs-netherlands-1.jpg" alt="Image" width="500" height="300">
# ## Introduction
#
# In this tutorial, we will learn how to scrape data from the ICC Cricket website (www.icc-cricket.com) using Python. We will focus on extracting information about cricket teams and players.
#
# ### Tools Required
#
# - Python (3.x)
# - Beautiful Soup (for HTML parsing)
# - Requests (for making HTTP requests)
#
# ## Setup
#
# Before we start, make sure you have the required libraries installed:
#
# ```bash
# pip install beautifulsoup4
# pip install requests

# %% [markdown]
# # Before Scraping: Learning about Requests and Beautiful Soup (bs4)
#
# Before we dive into web scraping, it's important to understand the two essential libraries we'll be using: `requests` and `Beautiful Soup` (bs4).

# %% [markdown]
# ## Making Requests
# In this section, we'll explore how to make HTTP requests using markup.

# %% [markdown]
# ### Introduction
#
# Markup languages like HTML or Markdown do not have native capabilities for making HTTP requests. However, you can incorporate code snippets in various languages to demonstrate this functionality.

# %% [markdown]
# ### Making GET Requests
#
# To make a GET request, you can use a language like Python. Here's an example using the `requests` library:
#
# ```python
# import requests
#
# response = requests.get('https://api.example.com/endpoint')
# print(response.text)

# %% [markdown]
# ### Making POST Requests
#
# If you need to send data to a server, you can use a POST request. Here's an example in Python:
#
# ```python
# import requests
#
# data = {'key1': 'value1', 'key2': 'value2'}
# response = requests.post('https://api.example.com/endpoint', data=data)
# print(response.text)

# %% [markdown]
# ### Handling Responses
#
# After making a request, you'll receive a response from the server. This response contains information like status codes, headers, and the actual content. You can parse and use this data as needed.
#
# For example, to access the status code in Python:
#
# ```python
# print(response.status_code)

# %% [markdown]
# ### Additional Notes
#
# - Always ensure that you have the necessary permissions and credentials when making requests to protected resources.
# - Consider error handling and exception management in your code for a robust application.
# - Check the documentation of the language or library you're using for more advanced request options and features.

# %%
# Import the requests library
import requests

# Define the URL to scrape
url = 'https://www.icc-cricket.com/match/101865#scorecard'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    print('Request successful') 
    # Print the HTML content of the page
    print(response.text)
else:
    # Print an error message along with the status code if the request was not successful
    print('Error:', response.status_code)
# Out:
# Request successful
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
#     <meta name="twitter:title" content="India 191/5 vs Australia 188 | India won by 5 wickets | ICC"/>
# <meta name="description" content="Follow the live scores of the India won by 5 wickets India vs Australia at Wankhede Stadium, Mumbai. Read the commentary, team updates and detailed match info!"/>
# <meta name="twitter:description" content="Follow the live scores of the India won by 5 wickets India vs Australia at Wankhede Stadium, Mumbai. Read the commentary, team updates and detailed match info!"/>
# <meta property="og:title" content="India 191/5 vs Australia 188 | India won by 5 wickets | ICC"/>
# <title>India 191/5 vs Australia 188 | India won by 5 wickets | ICC</title>
# <meta property="og:description" content="Follow the live scores of the India won by 5 wickets India vs Australia at Wankhede Stadium, Mumbai. Read the commentary, team updates and detailed match info!"/>
#
#
# <script>
#
#     var dataLayer = [{
#         'user_language':'English',
#         'web_domain':'www.icc-cricket.com',
#         'page_type':'/match/101865'
#     }];
#
# </script>
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-T7DPH24');</script>
# <!-- End Google Tag Manager -->
#
#
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta name="apple-itunes-app" content="app-id=956440606"/>
#
#     <link rel="manifest" href="/resources/prod/v8.32.0/manifest.json">
#
#     <link rel="shortcut icon" href="/resources/prod/v8.32.0/i/elements/favicon.ico" />
#
#
#
#
#     <script type="application/ld+json">
#
#
#
#         {
#             "@context": "https://schema.org/",
#             "@type": "Event",
#             "name": "India vs Australia (India v Australia - 2023 Men's ODI Series)",
#             "eventStatus": "Complete",
#             "startDate": "03/17/2023 08:00:00 AM",
#             "homeTeam": {
#                 "@type": "SportsTeam",
#                 "name": "India"
#             },
#             "awayTeam": {
#                 "@type": "SportsTeam",
#                 "name": "Australia"
#             },
#             "location": {
#                 "@type": "Place",
#                 "name": "Wankhede Stadium",
#                 "address": {
#                     "addressLocality": "Mumbai"
#                 }
#             },
#             "url": "https://www.icc-cricket.com/match/101865",
#             "creator": ["ICC"],
#             "keywords": ["Match Centre"]
#         }
#     </script>
#
#
# <!--
# Calculates the game dates for a match
# @param {Object} match - the scoring or fixture list item for a match
# @return {String} - the match days
#   -->
#
#
# <!--
# Calculates the number of days for a match
# @param {Object} match - the scoring or fixture list item for a match
# @return {Integer} - the number of days the match spans for
#   -->
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
#
# !function(e,t,n,c,i,a,s){i=i||"EcalWidget",e.EcalWidgetObject=i,e[i]=e[i]||
# function(){(e[i].q=e[i].q||
# []).push(arguments)},a=t.createElement(n),s=t.getElementsByTagName(n)
# [0],e[i].u=c,a.async=1,a.src=c,s.parentNode.insertBefore(a,s)}
# (window,document,"script","//sync.ecal.com/button/v1/main.js");
# window.addEventListener('load', function() {
#  var eCalButton = document.querySelector('.ecal-widget-button');
#  if ( eCalButton ) {
#  ecalWidget = EcalWidget.init({
#  apiKey: '819429e66b5b53415a1116473a3964235913f318579b7',
#  widgetId: '5a2f4ce25b5a427d4c8b4568'
#  });
# eCalButton.addEventListener('click',
# function() {
#  window.ecalWidget.show({
#  category: this.getAttribute('data-ecal-category').split(',')
#  });
#  });
#  };
#  });
#
# </script>
#
#
#     <link href="https://fonts.googleapis.com/css?family=Hind+Siliguri:300,400,600" rel="stylesheet">
#
#     <!-- Polyfill service provided by the FT - https://github.com/Financial-Times/polyfill-service -->
# 	<script src="https://cdn.polyfill.io/v2/polyfill.min.js"></script>
#
#     <link rel="stylesheet" href="/resources/prod/v8.32.0/styles/match-centre.css" />
#
#     <script>
# 		window.RESOURCE_VERSION = 'prod/v8.32.0';
# 	</script>
#
# </head>
# <body>
#
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-T7DPH24"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <!--
#     Start of Floodlight Tag: Please do not removeActivity name of this tag: ICC Website - VisitationURL of the webpage where the tag is expected to be placed: This tag must be placed between the <body> and </body> tags, as close as possible to the opening tag. Creation Date: 10/01/2019
# -->
#
# <iframe src="https://9282652.fls.doubleclick.net/activityi;src=9282652;type=iccre0;cat=iccwe0;u1=[user_language];u2=[user_country];u3=[page_type];u4=[web_domain];dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=;npa=;ord=[SessionID]?" width="1" height="1" frameborder="0" style="display:none"></iframe>
#
# <!-- End of Floodlight Tag: Please do not remove -->
#
# <script id="parsely-cfg" src="//cdn.parsely.com/keys/icc-cricket.com/p.js"></script>
#
#
#
# <div class="modal" id="VideoPlaylistModal" data-script="icc_video" data-widget="video-playlist-modal" data-site="icc">
#     <div class="modal__inner-wrapper">
#         <a href="#" class="modal__close js-modal-close">
# 	<svg class="modal__close-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-close"></use>
# 	</svg>
#         </a>
#         <div class="fixed-cols fixed-cols--modal fixed-cols--t-dark">
#             <div class="flex-grid">
#                 <div class="col-9 col-8-wide col-12-desk col-12-m fixed-cols__primary js-main-col">
#                     <div class="fixed-cols__primary-top js-single-video">
#                         <section class="video-player video-player--modal wrapper" data-widget="video-page-player" data-player-name="playlistPlayer">
#                             <div class="inline-player js-inline-player"
#                                 data-script="icc_video"
#                                 data-widget="video-player">
#
#                                 <video id="playlistPlayer"
#                                     data-video-id=""
#                                     data-account="3910869736001"
#                                     data-player="default"
#                                     data-embed="default"
#                                     class="video-js js-video video-js"
#                                     controls
#                                     autoplay=true
#                                     data-tracker-action="VIEW"
#                                     data-tracker-type="VIDEO"
#                                     data-tracker-id=""></video>
#                             </div>
#                         </section>
#
#                     </div>
#                 </div>
#                 <div class="col-3 col-4-wide col-12-desk fixed-cols__secondary js-sidebar-desktop js-active-video">
#                     <div class="modal__details col-12">
#                         <ul class="inline-list">
#                             <li class="video-player__date-day js-date"></li>
#                             <li class="video-player__date-year js-year"></li>
#                             <li class="video-player__duration">
# 	<svg class="duration-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-clock"></use>
# 	</svg>
#                                 <span class="js-duration"></span>
#                             </li>
#                         </ul>
#                         <h1 class="video-player__title js-title"></h1>
#                         <p class="video-player__description js-description"></p>
#                     </div>
#                     <p class="modal__no-videos-message js-no-video-message u-hide">Sorry, there are currently no videos available.</p>
#                     <div class="loading js-loader u-hide"></div>
#                     <div class="modal__upcoming-video js-upcoming-video u-hide">
#                         <span class="modal__upcoming-video-text">
#                             <span class="modal__upcoming-video-text--alt">UP</span> NEXT
#                         </span>
#                         <div class="modal__upcoming-video-container js-upcoming-video-container"></div>
#                     </div>
#                     <div class="modal__sidebar js-video-sidebar"></div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
#
# <!-- Retrieves the match status text, if there is one (match has outcome) -->
# <!-- Supports both /fixtures entries and /fixtures/<id>/scoring entries -->
#
# <!-- Requires getBattingTeam, getInningsSummary, isFollowOn -->
#
#
#
# <div id="match-scorer"
#     data-match-id="101865"
#     data-tournament-id="100249"
#     data-script="icc_match-centre"
#     data-widget="match-scorer">
# </div>
#
# <div id="event-cards"
#     class="event-card__container"
#     data-match-id="101865"
#     data-tournament-id="100249"
#     data-script="icc_match-centre"
#     data-widget="event-cards">
# </div>
#
# <nav class="mc-nav t-odi" data-widget="mc-nav" data-script="icc_match-centre">
# 	<a href="/home-page" class="mc-nav__btn mc-nav__back">
# 		<svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-chevron-left"></use></svg>
# 		<div class="icn icn-logo-icc-mob"></div>
# 	</a>
# 	<div class="mc-nav__btn mc-nav__matches-btn js-nav-matches-btn" role="button" tabindex="0"><div class="mc-nav__matches-count js-live-matches-count"></div><span class="long js-live-matches-btn-text">Live Matches</span><span class="short">Matches</span></div>
# 	<div class="mc-nav__match-summary">
# 		<div class="long">
# 			<div class="mc-nav__type">
# 				ODI
# 			</div>
# 			India v Australia
# 			<span class="mc-nav__match">India won by 5 wickets</span>
# 		</div>
# 		<div class="short">IND v AUS</div>
# 	</div>
# 	<div class="mc-nav__btn mc-nav__poll-btn js-nav-poll-btn" role="button" tabindex="0">
# 		<span class="mc-nav__poll-btn-txt">Fan Polls</span>
# 		<span class="mc-nav__poll-icon">
#             <svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-pulse"></use></svg>
#             <span class="mc-nav__poll-questions u-hide js-nav-poll-question-numbers"></span>
#         </span>
# 	</div>
#     <div class="mc-share js-share share" data-share-message="See the ICC Match Centre for India v Australia">
#     	<div class="mc-nav__btn mc-nav__share-btn js-share-btn" role="button" tabindex="0">Share<svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-share"></use></svg></div>
#         <ul class="mc-share__dropdown">
#             <li class="mc-share__option mc-share__option--twitter js-social-option" data-social-service="twitter" role="button" tabindex="0">
#                 <svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-twitter"></use></svg>
#             </li>
#             <li class="mc-share__option mc-share__option--facebook js-social-option" data-social-service="facebook" role="button" tabindex="0">
#                 <svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-facebook"></use></svg>
#             </li>
#         </ul>
#     </div>
# </nav>
#
#
# <main class="mc__content mc__content--c " data-widget="mc" data-match-state="C">
#
#
#     <nav class="mc__menu mc-menu mc-menu--no-video js-tab-menu">
#         <ul>
#                 <li class="mc-menu__item js-menu-item mc-menu__item--overview"
#                     data-tab="#overview"
#                     role="button" tabindex="0"
#                     data-nav-index="0"
#                     style="">Overview</li>
#                 <li class="mc-menu__item js-menu-item is-inactive"
#                     data-tab="#scorecard"
#                     role="button" tabindex="0"
#                     data-nav-index="1"
#                     style="">Scorecard</li>
#                 <li class="mc-menu__item js-menu-item "
#                     data-tab="#videos"
#                     role="button" tabindex="0"
#                     data-nav-index="2"
#                     style="">Videos</li>
#                 <li class="mc-menu__item js-menu-item is-inactive"
#                     data-tab="#hawk-eye"
#                     role="button" tabindex="0"
#                     data-nav-index="3"
#                     style="">Hawk-eye</li>
#                 <li class="mc-menu__item js-menu-item "
#                     data-tab="#teams"
#                     role="button" tabindex="0"
#                     data-nav-index="4"
#                     style="">Teams</li>
#                 <li class="mc-menu__item js-menu-item "
#                     data-tab="#social"
#                     role="button" tabindex="0"
#                     data-nav-index="5"
#                     style="">Social</li>
#                 <li class="mc-menu__item js-menu-item "
#                     data-tab="#match-info"
#                     role="button" tabindex="0"
#                     data-nav-index="6"
#                     style="">Match Info</li>
#         </ul>
#     </nav>
#
#
#     <div id="overview" class="mc__score-panel t-odi mc__tab is-hidden">
#
#
#         <section class="scorebox t-odi "
#                  data-widget="scorebox"
#                  data-match-state="C"
#                  data-match-id="101865"
#                  data-tournament-id="100249">
#
#
# <picture
#     class="scorebox__BG "
#     data-widget="scorebox-bg"
#     data-venue-id="4">
#
#     <source media="(min-width: 1800px)" srcset="/resources/prod/v8.32.0/i/bg-elements/mc-bg-large.jpg, /resources/prod/v8.32.0/i/bg-elements/mc-bg-large@x2.jpg 2x">
#
#     <source media="(min-width: 1200px)" srcset="/resources/prod/v8.32.0/i/bg-elements/mc-bg-medium.jpg, /resources/prod/v8.32.0/i/bg-elements/mc-bg-medium@x2.jpg 2x">
#
#     <source media="(min-width: 840px)" srcset="/resources/prod/v8.32.0/i/bg-elements/mc-bg-small.jpg, /resources/prod/v8.32.0/i/bg-elements/mc-bg-small@x2.jpg 2x">
#
#     <source media="(min-width: 500px)" srcset="/resources/prod/v8.32.0/i/bg-elements/mc-bg-medium.jpg, /resources/prod/v8.32.0/i/bg-elements/mc-bg-medium@x2.jpg 2x">
#
#     <source srcset="/resources/prod/v8.32.0/i/bg-elements/mc-bg-small.jpg, /resources/prod/v8.32.0/i/bg-elements/mc-bg-small@x2.jpg 2x">
#
#     <img src="/resources/prod/v8.32.0/i/bg-elements/mc-bg-medium.jpg" alt="Cricket Venue - Default">
#
# </picture>
#
#
#             <div class="js-scorebox-content scorebox__content">
#                 <div class="js-scorebox"  data-broadcast="false">
#                             <div class="scorebox__summary ">
#     <div class="scorebox__summary-inner-container">
#         <div class="scorebox__type t-odi">ODI</div>
#         <span class="scorebox__tournament-info">India v Australia - 2023 Men's ODI Series<span class="scorebox__divider"></span>India won by 5 wickets<span class="scorebox__divider scorebox__divider--last"></span></span>
#         <span class="scorebox__time-venue js-match-time"></span>
#         <span class="scorebox__divider"></span>
#         <span class="scorebox__ms-venue">Wankhede Stadium, Mumbai, India</span>
#     </div>
# </div>
#
#
# <div class="scorebox__outcome">
#         India won by 5 wickets
# </div>
# <div class="scorebox__teams">
#     <div class="scorebox__team ">
# 		<div class="flag-20 flag--home IND"></div>
# 		<div class="flag-30 flag--home IND"></div>
#         <div class="scorebox__score match-score">
#             <span class="scorebox__team-name">India</span> -
#     <span class="match-score__runs">
#             191/5
#     </span>
#         <span class="match-score__overs">39.5/50 ov</span>
#         <span class="match-score__run-rate">RR: 4.79</span>
#         </div>
#     </div>
#     <div class="scorebox__team scorebox__team--loser">
# 		<div class="flag-20 flag--home AUS"></div>
# 		<div class="flag-30 flag--home AUS"></div>
#         <div class="scorebox__score match-score">
#             <span class="scorebox__team-name">Australia</span> -
#     <span class="match-score__runs">
#             188
#     </span>
#         <span class="match-score__overs">35.4/50 ov</span>
#         <span class="match-score__run-rate">RR: 5.27</span>
#         </div>
#     </div>
# </div>
# <div class="scorebox__match-report">
#
#
#
#
#
# </div>
#
#                 </div>
#             </div>
#         </section>
#
#
#
#         <div class="commentary js-ct u-hide"
#      data-widget="mc-commentary"
#      data-script="icc_match-centre"
#      data-match-id="101865"
#      data-tournament-id="100249"
#      data-match-state="C">
#
#      <header class="commentary__header">
#         <h3 class="commentary__title">Live Match Commentary</h3>
#
#         <ul class="commentary__headers js-live-blog-headers"></ul>
#
#         <ul class="toggle-nav">
#             <li class="toggle-nav__item js-tab-button" data-filter="live-blog">Live Blog</li>
#             <li class="toggle-nav__item js-tab-button is-active" data-filter="commentary">All</li>
#         </ul>
#      </header>
#
#      <div class="commentary__content">
#
#         <div class="commentary__tab-section u-hide" data-tab="live-blog">
#
#
#         </div>
#
#         <div class="commentary__tab-section" data-tab="commentary">
#
#             <div class="commentary__bbb js-bbb-container"
#                 data-widget="mc-bbb"
#                 data-match-id="101865"
#                 data-tournament-id="100249"
#                 data-match-state="C">
#
#                 <div class="js-chunks-container">
#
#                     <div class="widget__footer u-text-center js-show-more js-commentary-loader">
#                         <button type="button" class="btn btn--round btn--arrow-down js-show-more-button" name="button">
#                             Show More
#                             <svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-double-chevron-down"></use></svg>
#                         </button>
#                         <div class="loading js-loader u-hide"></div>
#                     </div>
#                 </div>
#                 <div class="js-last-updated u-hide"></div>
#             </div>
#         </div>
#     </div>
#
# </div>
# <script charset="utf-8" type="text/javascript" src="//platform.twitter.com/widgets.js"></script>
# <script async defer src="//platform.instagram.com/en_US/embeds.js"></script>
#
#     </div>
#     <div id="scorecard" class="mc__details-panel t-odi mc__details-panel--no-video mc__tab js-tab  ">
# <div class="scorecard"
#     data-widget="scorecard"
#     data-match-id="101865"
#     data-tournament-id="100249">
#         <div class="scorecard__innings-container">
#
#                 <div class="scorecard__innings innings-1 js-innings-tab is-active">
#                     <div class="wrapper">
#                         <div class="col-12">
#
#                             <div class="scorecard__header u-hide-phablet">
#                                 <div class="flag-20 scorecard__team-badge AUS"></div>
#                                 <h3 class="scorecard__title">Australia Batting</h3>
#                             </div>
#
#                             <table class="table scorecard__table">
#                                 <thead>
#                                     <tr class="table-head">
#                                         <th class="table-head__cell scorecard__head-cell scorecard__head-cell--main">
#                                             <span class="u-hide-phablet">Batters</span>
#                                             <span class="u-show-phablet">Australia Batting</span>
#                                         </th>
#                                         <th class="table-head__cell scorecard__head-cell">R</th>
#                                         <th class="table-head__cell scorecard__head-cell">B</th>
#                                         <th class="table-head__cell scorecard__head-cell u-hide-phablet">4s</th>
#                                         <th class="table-head__cell scorecard__head-cell u-hide-phablet">6s</th>
#                                         <th class="table-head__cell scorecard__head-cell">SR</th>
#                                     </tr>
#                                 </thead>
#                                 <tbody>
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/1020">
#                     <span class="scorecard__player-name long">Travis Head</span><span class="scorecard__player-name short">TM Head</span>
#                         <span class="scorecard__dismissal">b Mohammed Siraj</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/1020">
#                     <strong>5</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/1020">
#                     10
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/1020">
#                     1
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/1020">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/1020">
#                     50.00
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/221">
#                     <span class="scorecard__player-name long">Mitchell Marsh</span><span class="scorecard__player-name short">MR Marsh</span>
#                         <span class="scorecard__dismissal">c Mohammed Siraj b Ravindra Jadeja</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/221">
#                     <strong>81</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/221">
#                     65
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/221">
#                     10
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/221">
#                     5
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/221">
#                     124.61
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/271">
#                     <span class="scorecard__player-name long">Steve Smith</span><span class="scorecard__player-name short">SPD Smith</span>
#                         <span class="scorecard__status scorecard__status--cpt">CPT</span>
#                         <span class="scorecard__dismissal">c KL Rahul b Hardik Pandya</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/271">
#                     <strong>22</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/271">
#                     30
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/271">
#                     4
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/271">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/271">
#                     73.33
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/4029">
#                     <span class="scorecard__player-name long">Marnus Labuschagne</span><span class="scorecard__player-name short">M Labuschagne</span>
#                         <span class="scorecard__dismissal">c Ravindra Jadeja b Kuldeep Yadav</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4029">
#                     <strong>15</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4029">
#                     22
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4029">
#                     1
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4029">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4029">
#                     68.18
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/4088">
#                     <span class="scorecard__player-name long">Josh Inglis</span><span class="scorecard__player-name short">JP Inglis</span>
#                         <span class="scorecard__status scorecard__status--wkt">WKT</span>
#                         <span class="scorecard__dismissal">b Mohammed Shami</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4088">
#                     <strong>26</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4088">
#                     27
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4088">
#                     1
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4088">
#                     1
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4088">
#                     96.29
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/4093">
#                     <span class="scorecard__player-name long">Cameron Green</span><span class="scorecard__player-name short">C Green</span>
#                         <span class="scorecard__dismissal">b Mohammed Shami</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4093">
#                     <strong>12</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4093">
#                     19
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4093">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4093">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/4093">
#                     63.15
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/282">
#                     <span class="scorecard__player-name long">Glenn Maxwell</span><span class="scorecard__player-name short">GJ Maxwell</span>
#                         <span class="scorecard__dismissal">c Hardik Pandya b Ravindra Jadeja</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/282">
#                     <strong>8</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/282">
#                     10
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/282">
#                     1
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/282">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/282">
#                     80.00
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/964">
#                     <span class="scorecard__player-name long">Marcus Stoinis</span><span class="scorecard__player-name short">MP Stoinis</span>
#                         <span class="scorecard__dismissal">c Shubman Gill b Mohammed Shami</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/964">
#                     <strong>5</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/964">
#                     8
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/964">
#                     1
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/964">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/964">
#                     62.50
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/942">
#                     <span class="scorecard__player-name long">Sean Abbott</span><span class="scorecard__player-name short">SA Abbott</span>
#                         <span class="scorecard__dismissal">c Shubman Gill b Mohammed Siraj</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/942">
#                     <strong>0</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/942">
#                     7
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/942">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/942">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/942">
#                     0.00
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player scorecard__highlighted-row">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/490">
#                     <span class="scorecard__player-name long">Mitchell Starc</span><span class="scorecard__player-name short">MA Starc</span>
#                         <span class="scorecard__status scorecard__status--not-out">NOT OUT</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/490">
#                     <strong>4</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/490">
#                     10
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/490">
#                     1
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/490">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/490">
#                     40.00
#                 </a>
#             </td>
#         </tr>
#
#
#         <tr class="table-body scorecard__table-body js-mc-scorecard-player ">
#             <td class="u-no-padding table-body__cell table-body__cell--main">
#                 <span class="scorecard__video-icon js-video-item" data-ui-modal="#VideoPlaylistModal">
# 	<svg class="scorecard__caret-icon">
# 		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-caret-down"></use>
# 	</svg>
#                 </span>
#                 <a class=" scorecard__cell scorecard__cell--main  u-link-reset u-show" href="/rankings/mens/player-rankings/958">
#                     <span class="scorecard__player-name long">Adam Zampa</span><span class="scorecard__player-name short">A Zampa</span>
#                         <span class="scorecard__dismissal">c KL Rahul b Mohammed Siraj</span>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/958">
#                     <strong>0</strong>
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class="scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/958">
#                     6
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/958">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell u-hide-phablet">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/958">
#                     0
#                 </a>
#             </td>
#             <td class="u-no-padding table-body__cell">
#                 <a class=" scorecard__cell u-link-reset u-show" href="/rankings/mens/player-rankings/958">
#                     0.00
#                 </a>
#             </td>
#         </tr>
#
#
#                                     <tr class="table-body scorecard__table-body">
#                                         <td class="table-body__cell scorecard__cell table-body__cell--main">
#                                             <span class="scorecard__fixed-title"><strong>Extras</strong></span> <span class="scorecard__detailed">(w 3, lb 7)</span>
#                                         </td>
#                                         <td class="table-body__cell scorecard__cell"><strong>10</strong></td>
#                                         <td class="table-body__cell scorecard__cell"></td>
#                                         <td class="table-body__cell scorecard__cell"></td>
#                                         <td class="table-body__cell scorecard__cell u-hide-phablet"></td>
#                                         <td class="table-body__cell scorecard__cell u-hide-phablet"></td>
#                                     </tr>
#                                     <tr class="table-body scorecard__table-body scorecard__table-body--dark">
#                                         <td class="table-body__cell scorecard__cell table-body__cell--main"><span class="scorecard__fixed-title"><strong>Total</strong></span> <span class="scorecard__detailed">(<strong>all out</strong>, <strong>35.4</strong> overs)</span></td>
#                                         <td class="table-body__cell scorecard__cell"><strong>188</strong></td>
#                                         <td class="table-body__cell scorecard__cell"></td>
#                                         <td class="table-body__cell scorecard__cell"></td>
#                                         <td class="table-body__cell scorecard__cell u-hide-phablet"></td>
#                                         <td class="table-body__cell scorecard__cell u-hide-phablet"></td>
#                                     </tr>
#                                 </tbody>
#                             </table>
#                             <table class="table scorecard__table scorecard__fow">
#                                 <thead>
#                                     <tr class="table-body scorecard__table-body">
#                                         <th class="table-head__cell scorecard__head-cell scorecard__head-cell--main">Fall of Wickets</th>
#                                     </tr>
#                                 </thead>
#                                 <tbody>
#                                     <tr><td class="table-body__cell scorecard__cell table-body__cell--main">
#                                     <p>        1-5 (TM Head, 1.6 ov)
# ,         2-77 (SPD Smith, 12.3 ov)
# ,         3-129 (MR Marsh, 19.4 ov)
# ,         4-139 (M Labuschagne, 22.4 ov)
# ,         5-169 (JP Inglis, 27.5 ov)
# ,         6-174 (C Green, 29.3 ov)
# ,         7-184 (MP Stoinis, 31.3 ov)
# ,         8-184 (GJ Maxwell, 32.2 ov)
# ,         9-188 (SA Abbott, 33.4 ov)
# ,         10-188 (A Zampa, 35.4 ov)
# </p>
#                                     </td></tr>
#                                 </tbody>
#                             </table>
#
#                             <div class="scorecard__header u-hide-phablet">
#                                 <div class="flag-20 scorecard__team-badge IND"></div>
#                                 <h3 class="scorecard__title">India Bowling</h3>
#                             </div>
#                             <table class="table scorecard__table">
#                                 <thead>
#                                     <tr>
#                                         <th class="table-head__cell scorecard__head-cell scorecard__head-cell--main">
#                                             <span class="u-hide-phablet">Bowlers</span>
#                                             <span class="u-show-phablet">India Bowling</span>
#                                         </th>
#                                         <th class="table-head__cell scorecard__head-cell">O</th>
#                                         <th class="table-head__cell scorecard__head-cell u-hide-phablet">M</th>
#                                         <th class="table-head__cell scorecard__head-cell">R</th>
#                                         <th class="table-head__cell scorecard__head-cell">W</th>
#                                         <th class="table-head__cell scorecard__head-cell">Econ</th>
#                                         <th class="table-head__cell scorecard__head-cell u-hide-phablet">Dots</th>
#                                     </tr>
#                                 </thead>
#                                 <tbody>
#
# ...
#                     </div> <div class="close"><a class="confirmButton btn">Apply</a></div>
#                   </div>
#
#                   <div id="noOptionsFilterCntr" class="filterPanel hidden">
#                     <div class="content">
#                       <div class="defaultFilter">
#                         <h1 class=""></h1>
#                         <div class="defaultFilterContent">
#                           <h3 class="">No options available for this feature.</h3>
#                         </div><!-- END content -->
#                       </div>
#                     </div>
#                   </div>
#
#                   <div id="inningsFilterCntr" class="filterPanel hidden">
#                       <div class="content">
#                       <div class="defaultFilter">
#                         <h1 class=""></h1>
#                         <div class="defaultFilterContent">
#                           <div class="selectCntr">
#                             <div class='filterLabel'>Innings</div>
#                             <select style="" class="inningsSelect" name="" id=""></select>
#                           </div>
#                        </div>
#                       <div class="cl"></div>
#                       </div>
#                       </div> <div class="close"><a class="confirmButton">Apply</a></div>
#                   </div>
#
#                   <div id="latestOverFilterCntr" class="filterPanel hidden" style="display:none;">
#                       <div class="content">
#                        <div class="trajPanel">
#                         <div class="menu">
#                             <ul>
#                                 <!--<li class="left active"><a>Latest Over</a></li>-->
#                                 <li class="left"><a>All Balls</a></li>
#                                 <li class="right"><a>Wickets</a></li>
#                             </ul>
#                         </div>
#                         <div id="traj-description2" class=""></div>
#                        </div>
#                      </div> <!-- END content -->
#                   </div>
#
#                   <div id="wicketsFilterCntr" class="filterPanel hidden">
#                       <div class="content">
#                        <div class="trajPanel">
#                         <div class="menu">
#                             <ul>
#                                 <!--<li class="left"><a>Latest Over</a></li>-->
#                                 <li class="left"><a>All Balls</a></li>
#                                 <li class="right active"><a>Wickets</a></li>
#                             </ul>
#                         </div>
#                         <div class="trajWickets">
#                             <div class="selectCntr">
#                              <select style="" class="inningsSelect" name="" id=""></select>
#                             </div>
#                             <div class="content">
#                               <ul></ul>
#                             </div>
#                        </div>
#                        </div>
#                      </div> <!-- END content -->
#                   </div>
#
#                   <div id="findABallFilterCntr" class="filterPanel hidden">
#                       <div class="content">
#                        <div class="trajPanel">
#                         <div class="menu">
#                             <ul>
#                                 <!--<li class="left"><a>Latest Over</a></li>-->
#                                 <li class="left active"><a>All Balls</a></li>
#                                 <li class="right"><a>Wickets</a></li>
#                             </ul>
#                             <div class="cl"></div>
#                         </div>
#                         <div class="trajMenuContent">
#                           <div class="selectCntr">
#                             <div class='filterLabel'>Innings</div>
#                             <select style="" class="inningsSelect" name="" id=""></select>
#                           </div>
#                             <div class="selectCntr">
#                               <div class='filterLabel'>Bowler</div>
#                               <select style="" class="bowlerSelect" name="" id=""></select>
#                             </div>
#
#                               <div class="selectCntr">
#                                 <div class='filterLabel'>Over</div>
#                                 <select style="" class="overSelect" name="" id=""></select>
#                               </div>
#
#                               <div class="selectCntr">
#                                 <div class='filterLabel'>Ball</div>
#                                 <select style="" class="ballSelect" name="" id=""></select>
#                               </div>
#
#                           </div>
#                        <div class="cl"></div>
#                        </div>
#                      </div> <!-- END content -->
#                      <div class="close"><a class="confirmButton btn">Apply</a></div>
#                   </div>
#
#                 </div>
#             </div>
#
#             <div id="hawkeye-nav" class="featureList"></div>
#
#         </div>
#
#     </section>
#     <!-- END hawkeyeContent -->
#
#   </div>
# </div>
#
#     </div>
#     <div id="teams" class="mc__details-panel mc__details-panel--no-video mc__tab js-tab is-hidden">
#
# <div class="mc-teams" data-widget="mc-teams" data-script="icc_match-centre"
#     data-match-id="101865"
#     data-tournament-id="100249">
#
#
#         <div class="mc-teams__column col-6 js-team-list">
#     <div class="mc-teams__header">
#         <div class="flag-15 mc-teams__flag IND"></div><span class="mc-teams__team-name"><span class="long">India</span><span class="short">IND</span> Playing XI</span>
#     </div>
#     <ul class="mc-team-list mc-team-list--playing-xi">
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">Shubman Gill</span>
#                 <span class="mc-team-list__player-name long">Shubman Gill</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">Ishan Kishan</span>
#                 <span class="mc-team-list__player-name long">Ishan Kishan</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">V Kohli</span>
#                 <span class="mc-team-list__player-name long">Virat Kohli</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">SK Yadav</span>
#                 <span class="mc-team-list__player-name long">Suryakumar Yadav</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">KL Rahul</span>
#                 <span class="mc-team-list__player-name long">KL Rahul</span>
#                     <span class="mc-team-list__badge mc-team-list__badge--wicket">WKT</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">HH Pandya</span>
#                 <span class="mc-team-list__player-name long">Hardik Pandya</span>
#                     <span class="mc-team-list__badge mc-team-list__badge--captain">CPT</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">RA Jadeja</span>
#                 <span class="mc-team-list__player-name long">Ravindra Jadeja</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">SN Thakur</span>
#                 <span class="mc-team-list__player-name long">Shardul Thakur</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">Kuldeep Yadav</span>
#                 <span class="mc-team-list__player-name long">Kuldeep Yadav</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">Mohammed Siraj</span>
#                 <span class="mc-team-list__player-name long">Mohammed Siraj</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">Mohammed Shami</span>
#                 <span class="mc-team-list__player-name long">Mohammed Shami</span>
#             </li>
#     </ul>
#         </div>
#         <div class="mc-teams__column col-6 js-team-list">
#     <div class="mc-teams__header">
#         <div class="flag-15 mc-teams__flag AUS"></div><span class="mc-teams__team-name"><span class="long">Australia</span><span class="short">AUS</span> Playing XI</span>
#     </div>
#     <ul class="mc-team-list mc-team-list--playing-xi">
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">TM Head</span>
#                 <span class="mc-team-list__player-name long">Travis Head</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">MR Marsh</span>
#                 <span class="mc-team-list__player-name long">Mitchell Marsh</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">SPD Smith</span>
#                 <span class="mc-team-list__player-name long">Steve Smith</span>
#                     <span class="mc-team-list__badge mc-team-list__badge--captain">CPT</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">M Labuschagne</span>
#                 <span class="mc-team-list__player-name long">Marnus Labuschagne</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">JP Inglis</span>
#                 <span class="mc-team-list__player-name long">Josh Inglis</span>
#                     <span class="mc-team-list__badge mc-team-list__badge--wicket">WKT</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">C Green</span>
#                 <span class="mc-team-list__player-name long">Cameron Green</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">GJ Maxwell</span>
#                 <span class="mc-team-list__player-name long">Glenn Maxwell</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">MP Stoinis</span>
#                 <span class="mc-team-list__player-name long">Marcus Stoinis</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">SA Abbott</span>
#                 <span class="mc-team-list__player-name long">Sean Abbott</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">MA Starc</span>
#                 <span class="mc-team-list__player-name long">Mitchell Starc</span>
#             </li>
#             <li class="mc-team-list__player">
#                 <span class="mc-team-list__player-name short">A Zampa</span>
#                 <span class="mc-team-list__player-name long">Adam Zampa</span>
#             </li>
#     </ul>
#         </div>
# </div>
#
#
#     </div>
#     <div id="social" class="mc__details-panel mc__details-panel--no-video mc__tab js-tab is-hidden">
#
#     <section>
#         <a class="twitter-timeline" href="https://twitter.com/ICC?ref_src=twsrc%5Etfw">Tweets by ICC</a> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#     </section>
#
#     </div>
#     <div id="match-info" class="mc__details-panel mc__details-panel--no-video mc__tab js-tab is-hidden">
#
#     <section class="match-info"
#         data-script="icc_match-centre" data-widget="mc-match-info"
#         data-match-id="101865"
#         data-tournament-id="100249">
#
#         <div class="match-info__details">
#             <ul>
#                 <li class="match-info__detail">
#                     <span class="match-info__label">Toss:</span>
#                     <span class="match-info__info js-toss">India who chose to bowl</span>
#                 </li>
#                 <li class="match-info__detail">
#                     <span class="match-info__label">Venue:</span>
#                     <span class="match-info__info">Wankhede Stadium, Mumbai</span>
#                 </li>
#                     <li class="match-info__detail">
#                         <span class="match-info__label">Umpires:</span>
#                         <span class="match-info__info">Nitin Menon, KN Ananthapadmanabhan, Virender Sharma, Anil Chaudhary</span>
#                     </li>
#                     <li class="match-info__detail">
#                         <span class="match-info__label">Match Referee:</span>
#                         <span class="match-info__info">Javagal Srinath</span>
#                     </li>
#             </ul>
#         </div>
#
#         <div class="match-info__notes match-notes js-notes">
#
#                     <div class="match-notes__innings">
#                         <h3 class="match-notes__innings-title"><span class="flag-15 match-notes__flag AUS"></span>Australia Innings</h3>
#                         <ul class="match-notes__details">
#                         </ul>
#                     </div>
#                     <div class="match-notes__innings">
#                         <h3 class="match-notes__innings-title"><span class="flag-15 match-notes__flag IND"></span>India Innings</h3>
#                         <ul class="match-notes__details">
#                         </ul>
#                     </div>
#         </div>
#     </section>
#
#     </div>
# </main>
#
# <div data-script="icc_match-centre" data-widget="mc-poll" data-gameweek="" class="">
#     <div class="poll js-question-container">
#         <header class="poll__header js-matchWeekPollButton">
#             Fan Polls
#             <div class="poll__header__icon">
#                 <svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-pulse"></use></svg>
#                 <span class="poll__header__count u-hide js-poll-question-number"></span>
#             </div>
#             <a href="#" class="poll__header__close js-options-close-btn">
#                 <svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-close"></use></svg>
#             </a>
#         </header>
#
#         <div class="poll__content">
#             <div class="js-options-container u-hide">
#                 <div class="js-option-render-container"></div>
#                 <div class="branding-strip"></div>
#             </div>
#
#             <div class="js-all-questions-container"></div>
#         </div>
#     </div>
# </div>
#
# <div data-script="icc_match-centre"
#     data-widget="mc-live-matches"
#     data-tournament-type="I,WI"
#     class="live-matches wrap-fixtures-abridged js-live-matches">
#     <div class="live-matches__content">
#         <header class="live-matches__header">
#             <h3 class="widget__title js-header-match-count"></h3>
#             <div class="live-matches__close js-close" tabindex="0" role="button"> <svg class="icon"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v8.32.0/i/svg-output/icons.svg#icn-close"></use></svg></div>
#         </header>
#         <div class="js-live-match-container"></div>
#     </div>
#     <div class="live-matches__underlay js-underlay"></div>
# </div>
#
#
#
#     <script src="/resources/prod/v8.32.0/scripts/vendors.js"></script>
#     <script src="/resources/prod/v8.32.0/scripts/client.js"></script>
#
#     <!--[if IE]> -->
#     <script type="text/javascript">
#         svg4everybody();
#     </script>
#     <!-- <![endif]-->
# </body>
# </html>

# %% [markdown]
# ## Web Scraping with Beautiful Soup
#
# In this section, we'll explore how to use Beautiful Soup, a Python library, for web scraping in your notebook.

# %% [markdown]
# ### Introduction
#
# Beautiful Soup is a powerful Python library used for web scraping purposes. It allows you to parse HTML or XML documents, extract data, and navigate through the document's structure.

# %% [markdown]
# ### Installing Beautiful Soup
#
# Before using Beautiful Soup, you need to install it. You can do this via pip:
#
# ```bash
# pip install bs4

# %% [markdown]
# ### Basic Usage
#
# To start using Beautiful Soup, you first need to import it in your Python script or notebook:
#
# ```python
# from bs4 import BeautifulSoup

# %% [markdown]
# ### Assuming 'html_content' contains your HTML content
# soup = BeautifulSoup(html_content, 'html.parser')

# %% [markdown]
# ### Navigating the Document
#
# Beautiful Soup provides methods to navigate through the document's structure. For example, to find all links (`<a>` tags), you can use:
#
# ```python
# links = soup.find_all('a')
# for link in links:
#     print(link.get('href'))

# %% [markdown]
# ### Extracting Data
#
# You can extract specific data by targeting HTML elements or their attributes. For instance, to get the text inside a `<div>` with a class of 'content':
#
# ```python
# content_div = soup.find('div', class_='content')
# print(content_div.text)

# %%
# Import necessary libraries
import json  # For working with JSON files
import requests  # For making HTTP requests
from bs4 import BeautifulSoup  # For parsing HTML

# Define the file path for the JSON file
file_path = 'D:\\data\\json\\matchlinks.json'

# Read the JSON file that we made using selenium into a dictionary
with open(file_path, 'r') as json_file:
    my_dict = json.load(json_file)

# Now 'my_dict' contains the data from the JSON file
print(my_dict)
# Out:
# {'India': [["ODI\nAustralia won by 66 runs\nIndia 286\nAustralia 352/7\n3rd ODI, India v Australia - 2023/24 Men's ODI Series | Saurashtra Cricket Association Stadium, Rajkot\nWed 27 September\nMatch Centre", 'https://www.icc-cricket.com/match/102964'], ["ODI\nIndia won by 99 runs (DLS method)\nIndia 399/5\nAustralia 217\nIndia won by 99 runs (DLS method), India v Australia - 2023/24 Men's ODI Series | Holkar Cricket Stadium, Indore\nSun 24 September\nMatch Centre", 'https://www.icc-cricket.com/match/102963'], ["ODI\nIndia won by 5 wickets\nIndia 281/5\nAustralia 276\nIndia won by 5 wickets, India v Australia - 2023/24 Men's ODI Series | Punjab Cricket Association Stadium, Mohali\nFri 22 September\nMatch Centre", 'https://www.icc-cricket.com/match/102962'], ['ODI Final\nIndia won by 10 wickets\nIndia 51/0\nSri Lanka 50\nFinal, Asia Cup 2023 | R.Premadasa Stadium, Khettarama\nSun 17 September\nMatch Centre', 'https://www.icc-cricket.com/match/102846'], ['ODI\nBangladesh won by 6 runs\nIndia 259\nBangladesh 265/8\nBangladesh won by 6 runs, Asia Cup 2023 | R.Premadasa Stadium, Khettarama\nFri 15 September\nMatch Centre', 'https://www.icc-cricket.com/match/102840'], ['ODI\nIndia won by 41 runs\nIndia 213\nSri Lanka 172\nIndia won by 41 runs, Asia Cup 2023 | R.Premadasa Stadium, Khettarama\nTue 12 September\nMatch Centre', 'https://www.icc-cricket.com/match/102844'], ['ODI\nIndia won by 228 runs\nPakistan 128\nIndia 356/2\nIndia won by 228 runs, Asia Cup 2023 | R.Premadasa Stadium, Khettarama\nSun 10 September\nMatch Centre', 'https://www.icc-cricket.com/match/102843'], ['ODI\nIndia won by 10 wickets (DLS method)\nIndia 147/0\nNepal 230\nIndia won by 10 wickets (DLS method), Asia Cup 2023 | Pallekele International Cricket Stadium\nMon 04 September\nMatch Centre', 'https://www.icc-cricket.com/match/102836'], ['ODI\nMatch Abandoned\nPakistan\nIndia 266\nMatch Abandoned, Asia Cup 2023 | Pallekele International Cricket Stadium\nSat 02 September\nMatch Centre', 'https://www.icc-cricket.com/match/102835'], ["ODI\nIndia won by 200 runs\nWest Indies 151\nIndia 351/5\n3rd ODI, West Indies v India - 2023 Men's ODI Series | Brian Lara Cricket Academy, Tarouba\nTue 01 August\nMatch Centre", 'https://www.icc-cricket.com/match/102722'], ["ODI\nWest Indies won by 6 wickets\nWest Indies 182/4\nIndia 181\n2nd ODI, West Indies v India - 2023 Men's ODI Series | Kensington Oval, Bridgetown\nSat 29 July\nMatch Centre", 'https://www.icc-cricket.com/match/102724'], ["ODI\nIndia won by 5 wickets\nWest Indies 114\nIndia 118/5\n1st ODI, West Indies v India - 2023 Men's ODI Series | Kensington Oval, Bridgetown\nThu 27 July\nMatch Centre", 'https://www.icc-cricket.com/match/102723'], ["ODI\nAustralia won by 21 runs\nIndia 248\nAustralia 269\nAustralia won by 21 runs, India v Australia - 2023 Men's ODI Series | MA Chidambaram Stadium, Chennai\nWed 22 March\nMatch Centre", 'https://www.icc-cricket.com/match/101867'], ["ODI\nAustralia won by 10 wickets\nIndia 117\nAustralia 121/0\nAustralia won by 10 wickets, India v Australia - 2023 Men's ODI Series | YS Raja Reddy Stadium, Kadapa\nSun 19 March\nMatch Centre", 'https://www.icc-cricket.com/match/101866'], ["ODI\nIndia won by 5 wickets\nIndia 191/5\nAustralia 188\nIndia won by 5 wickets, India v Australia - 2023 Men's ODI Series | Wankhede Stadium, Mumbai\nFri 17 March\nMatch Centre", 'https://www.icc-cricket.com/match/101865'], ["ODI\nIndia won by 90 runs\nIndia 385/9\nNew Zealand 295\n3rd ODI, India v New Zealand - 2023 Men's ODI Series | Holkar Cricket Stadium, Indore\nTue 24 January\nMatch Centre", 'https://www.icc-cricket.com/match/101870'], ["ODI\nIndia won by 8 wickets\nIndia 111/2\nNew Zealand 108\n2nd ODI, India v New Zealand - 2023 Men's ODI Series | Shaheed Veer Narayan Singh International Cricket Stadium\nSat 21 January\nMatch Centre", 'https://www.icc-cricket.com/match/101869'], ["ODI\nIndia won by 12 runs\nIndia 349/8\nNew Zealand 337\n1st ODI, India v New Zealand - 2023 Men's ODI Series | Rajiv Gan ...

# %%
#Lets see what in the dictionary
my_dict['India'][0][0]
# Out:
# "ODI\nAustralia won by 66 runs\nIndia 286\nAustralia 352/7\n3rd ODI, India v Australia - 2023/24 Men's ODI Series | Saurashtra Cricket Association Stadium, Rajkot\nWed 27 September\nMatch Centre"

# %%
teams = ['India', 'Afghanistan', 'Australia','Bangladesh', 'England', 'New Zealand', 'Pakistan', 'South Africa', 'Netherlands' , 'Sri Lanka' ]

# %%
# Create an empty dictionary 'd'
d = dict()

# Loop through key-value pairs in 'my_dict'
for k, v in my_dict.items():
    print("<----------Had----------->")
    print(k, len(v))
    
    links = []  # Initialize an empty list for storing links
    
    # Loop through matches in 'v'
    for match in v:
        count = -1
        
        # Loop through teams in 'teams' so that we can capture only those matches that are played between ODI teams
        for i in teams:
            if match[0].__contains__(i):
                count = count + 1
        
        # Append match link if count is 1
        if count == 1:
            links.append(match[1])
        
        # Break loop if the number of links reaches 50
        if len(links) >= 50:
            break
    
    print("<----------Taking----------->")
    print(k, len(links))
    d[k] = links  # Assign links to the key k in dictionary 'd'
# Out:
# <----------Had----------->
# India 304
# <----------Taking----------->
# India 50
# <----------Had----------->
# Afghanistan 119
# <----------Taking----------->
# Afghanistan 45
# <----------Had----------->
# Australia 273
# <----------Taking----------->
# Australia 50
# <----------Had----------->
# Bangladesh 186
# <----------Taking----------->
# Bangladesh 50
# <----------Had----------->
# England 267
# <----------Taking----------->
# England 50
# <----------Had----------->
# New Zealand 266
# <----------Taking----------->
# New Zealand 50
# <----------Had----------->
# Pakistan 257
# <----------Taking----------->
# Pakistan 50
# <----------Had----------->
# South Africa 234
# <----------Taking----------->
# South Africa 50
# <----------Had----------->
# Netherlands 68
# <----------Taking----------->
# Netherlands 36
# <----------Had----------->
# Sri Lanka 296
# <----------Taking----------->
# Sri Lanka 50

# %%
for i in d.keys():
    print(f"<------------- Doing for {i} ---------------->")
    for j in d[i]:
        try:
            url=j
            response = requests.get(url)
            soup = BeautifulSoup(response.content, 'html.parser')
            script_tag=soup.find("script",type="application/ld+json")
            result_str=soup.find('div','scorebox__outcome').text.replace("\n",'').strip()
            script_tag=soup.find("script",type="application/ld+json")
            data = json.loads(script_tag.string)
            
            #Taking the meta data
            match={
            "date":data['startDate'],
            "home":data['homeTeam']['name'],
            'away':data['awayTeam']['name'],
            "place":data['location']['name'],
            "result":result_str}
            
            
            #Taking data out of score board.
            try:
                novert0=soup.find_all('div',"scorebox__team")[0].find('span',"match-score__overs").text.replace('\n','').strip()
            except AttributeError:
                novert0=''
            try:
                novert1=soup.find_all('div',"scorebox__team")[1].find('span',"match-score__overs").text.replace('\n','').strip()
            except AttributeError:
                novert1=''
            try:
                rrt0=soup.find_all('div',"scorebox__team")[0].find('span',"match-score__run-rate").text.replace('\n','').strip()
            except AttributeError:
                rrt0=''
            try:
                rrt1=soup.find_all('div',"scorebox__team")[1].find('span',"match-score__run-rate").text.replace('\n','').strip()
            except AttributeError:
                rrt1=''
            namet0=soup.find_all('div',"scorebox__team")[0].find('span',"scorebox__team-name").text.replace('\n','').strip()
            namet1=soup.find_all('div',"scorebox__team")[1].find('span',"scorebox__team-name").text.replace('\n','').strip()
            try:
                scoret0=soup.find_all('div',"scorebox__team")[0].find('span',"match-score__runs").text.replace('\n','').strip()
            except AttributeError:
                scoret0=''

            try:
                scoret1=soup.find_all('div',"scorebox__team")[1].find('span',"match-score__runs").text.replace('\n','').strip()
            except AttributeError:
                scoret1=''
                
                
            # Extract batting and bowling information    
            tables=soup.find_all("table",class_="table scorecard__table")
            batting=dict()
            for table in tables[0::2]: #Only batting tables taken by slicing
                player_data = []
                extras=''
                for row in table.find('tbody').find_all('tr'):
                    try:
                        cols = row.find_all('td')
                        player_name = cols[0].find('span', class_='scorecard__player-name').text
                        try:
                            dismisal_name=cols[0].find('span', class_='scorecard__dismissal').text

                        except:
                            dismisal_name=""
                        runs = cols[1].strong.text
                        balls_faced = cols[2].text.strip()
                        fours = cols[3].text.strip()
                        sixes = cols[4].text.strip()
                        strike_rate = cols[5].text.strip()

                        player_data.append({
                            "Player Name": player_name,
                            "Dismissed by":dismisal_name ,
                            "Runs": runs,
                            "Balls Faced": balls_faced,
                            "Fours": fours,
                            "Sixes": sixes,
                            "Strike Rate": strike_rate
                        })
                    except:
                        if extras=='':
                            extras=cols[0].text.replace("\n",'')
                        else:
                            pass
                # Save data in a dictionary and append
                batting[table.tr.text.replace("\n",'').replace('Batters','').split("Batting")[0].strip()]=[player_data,extras]

            balling=dict()
            for table in tables[1:4:2]: #Only balling tables taken by slicing
                bowling_stats = []
                for row in table.find('tbody').find_all('tr'):
                    player_name=row.find('a', class_='scorecard__cell--main').span.text
                    player_data = row.find_all('a', class_='scorecard__cell u-link-reset u-show')
                    overs = player_data[0].text.strip()
                    maidens = player_data[1].text.strip()
                    runs = player_data[2].text.strip()
                    wickets = player_data[3].text.strip()
                    economy = player_data[4].text.strip()
                    dots = player_data[5].text.strip()

                    # Save data in a dictionary and append
                    bowling_stats.append({
                        'player_name':player_name,
                        'Overs': overs,
                        'Maidens': maidens,
                        'Runs': runs,
                        'Wickets': wickets,
                        'Economy': economy,
                        'Dots': dots
                    })


                # Save data in a dictionary and append
                balling[table.tr.text.replace("\n",'').replace('Bowlers','').split("Bowling")[0].strip()]=bowling_stats
            try:
                batt0=batting[namet0]
            except:
                batt0=["None","None"]
            try:
                batt1=batting[namet1]
            except:
                batt1=["None","None"]
            try:
                ballingt1=balling[namet1]
            except:
                ballingt1=[]
            try:
                ballingt0=balling[namet0]
            except:
                ballingt0=[]

            dicteam1 = {"Name":namet0,
            "score":scoret0,
            "overs":novert0,
            "rr":rrt0,
            "batting":batt0[0],
            "Extras":batt0[1],
            "balling":ballingt0}

            dicteam2 = {"Name":namet1,
            "score":scoret1,
            "overs":novert1,
            "rr":rrt1,
            "batting":batt1[0],
            "Extras":batt1[1],
            "balling":ballingt1}

            match["Team1"]=dicteam1
            match["Team2"]=dicteam2

            filenum=url.split("#")[0].split("/")[-1]

            match["match_id"]=filenum
            
            #Save the files individually to computer
            file_path = fr'D:\data\json\team_{i}_{filenum}.json'
            with open(file_path, 'w') as json_file:
                json.dump(match, json_file)
        except:
            pass
# Out:
# <------------- Doing for India ---------------->
# <------------- Doing for Afghanistan ---------------->
# <------------- Doing for Australia ---------------->
# <------------- Doing for Bangladesh ---------------->
# <------------- Doing for England ---------------->
# <------------- Doing for New Zealand ---------------->
# <------------- Doing for Pakistan ---------------->
# <------------- Doing for South Africa ---------------->
# <------------- Doing for Netherlands ---------------->
# <------------- Doing for Sri Lanka ---------------->

# %%
d={"India":["https://www.icc-cricket.com/match/102846#scorecard"]}

# %%
tables[0].tr.text.replace("\n",'').replace('Batters','').split("Batting")[0].strip()
# Out:
# 'Sri Lanka'

# %%
match
# Out:
# {'date': '09/17/2023 09:30:00 AM',
#  'home': 'India',
#  'away': 'Sri Lanka',
#  'place': 'R.Premadasa Stadium',
#  'result': 'India won by 10 wickets',
#  'Team1': {'Name': 'India',
#   'score': '51/0',
#   'overs': '6.1/50 ov',
#   'rr': 'RR: 8.27',
#   'batting': [{'Player Name': 'Shubman Gill',
#     'Dismissed by': '',
#     'Runs': '27',
#     'Balls Faced': '19',
#     'Fours': '6',
#     'Sixes': '0',
#     'Strike Rate': '142.10'},
#    {'Player Name': 'Ishan Kishan',
#     'Dismissed by': '',
#     'Runs': '23',
#     'Balls Faced': '18',
#     'Fours': '3',
#     'Sixes': '0',
#     'Strike Rate': '127.77'},
#    {'Player Name': 'Rohit Sharma',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'},
#    {'Player Name': 'Virat Kohli',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'},
#    {'Player Name': 'KL Rahul',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'},
#    {'Player Name': 'Hardik Pandya',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'},
#    {'Player Name': 'Ravindra Jadeja',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'},
#    {'Player Name': 'Washington Sundar',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'},
#    {'Player Name': 'Jasprit Bumrah',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'},
#    {'Player Name': 'Kuldeep Yadav',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'},
#    {'Player Name': 'Mohammed Siraj',
#     'Dismissed by': '',
#     'Runs': '-',
#     'Balls Faced': '-',
#     'Fours': '-',
#     'Sixes': '-',
#     'Strike Rate': '-'}],
#   'Extras': 'Extras (lb 1)',
#   'balling': [{'player_name': 'Jasprit Bumrah',
#     'Overs': '5',
#     'Maidens': '1',
#     'Runs': '23',
#     'Wickets': '1',
#     'Economy': '4.60',
#     'Dots': '20'},
#    {'player_name': 'Mohammed Siraj',
#     'Overs': '7',
#     'Maidens': '1',
#     'Runs': '21',
#     'Wickets': '6',
#     'Economy': '3.00',
#     'Dots': '34'},
#    {'player_name': 'Hardik Pandya',
#     'Overs': '2.2',
#     'Maidens': '0',
#     'Runs': '3',
#     'Wickets': '3',
#     'Economy': '1.28',
#     'Dots': '12'},
#    {'player_name': 'Kuldeep Yadav',
#     'Overs': '1',
#     'Maidens': '0',
#     'Runs': '1',
#     'Wickets': '0',
#     'Economy': '1.00',
#     'Dots': '5'}]},
#  'Team2': {'Name': 'Sri Lanka',
#   'score': '50',
#   'overs': '15.2/50 ov',
#   'rr': 'RR: 3.26',
#   'batting': [{'Player Name': 'Pathum Nissanka',
#     'Dismissed by': 'c Ravindra Jadeja b Mohammed Siraj',
#     'Runs': '2',
#     'Balls Faced': '4',
#     'Fours': '0',
#     'Sixes': '0',
#     'Strike Rate': '50.00'},
#    {'Player Name': 'Kusal Perera',
#     'Dismissed by': 'c KL Rahul b Jasprit Bumrah',
#     'Runs': '0',
#     'Balls Faced': '2',
#     'Fours': '0',
#     'Sixes': '0',
#     'Strike Rate': '0.00'},
#    {'Player Name': 'Kusal Mendis',
#     'Dismissed by': 'b Mohammed Siraj',
#     'Runs': '17',
#     'Balls Faced': '34',
#     'Fours': '3',
#     'Sixes': '0',
#     'Strike Rate': '50.00'},
#    {'Player Name': 'Sadeera Samarawickrama',
#     'Dismissed by': 'lbw Mohammed Siraj',
#     'Runs': '0',
#     'Balls Faced': '2',
#     'Fours': '0',
#     'Sixes': '0',
#     'Strike Rate': '0.00'},
#    {'Player Name': 'Charith Asalanka',
#     'Dismissed by': 'c Ishan Kishan b Mohammed Siraj',
#     'Runs': '0',
#     'Balls Faced': '1',
#     'Fours': '0',
#     'Sixes': '0',
#     'Strike Rate': '0.00'},
#    {'Player Name': 'Dhananjaya de Silva',
#     'Dismissed by': 'c KL Rahul b Mohammed Siraj',
#     'Runs': '4',
#     'Balls Faced': '2',
#     'Fours': '1',
#     'Sixes': '0',
#     'Strike Rate': '200.00'},
#    {'Player Name': 'Dasun Shanaka',
#     'Dismissed by': 'b Mohammed Siraj',
#     'Runs': '0',
#     'Balls Faced': '4',
#     'Fours': '0',
#     'Sixes': '0',
#     'Strike Rate': '0.00'},
#    {'Player Name': 'Dunith Wellalage',
#     'Dismissed by': 'c KL Rahul b Hardik Pandya',
#     'Runs': '8',
#     'Balls Faced': '21',
#     'Fours': '0',
#     'Sixes': '0',
#     'Strike Rate': '38.09'},
#    {'Player Name': 'Dushan Hemantha',
#     'Dismissed by': '',
#     'Runs': '13',
#     'Balls Faced': '15',
#     'Fours': '1',
#     'Sixes': '0',
#     'Strike Rate': '86.66'},
#    {'Player Name': 'Pramod Madushan',
#     'Dismissed by': 'c Virat Kohli b Hardik Pandya',
#     'Runs': '1',
#     'Balls Faced': '6',
#     'Fours': '0',
#     'Sixes': '0',
#     'Strike Rate': '16.66'},
#    {'Player Name': 'Matheesha Pathirana',
#     'Dismissed by': 'c Ishan Kishan b Hardik Pandya',
#     'Runs': '0',
#     'Balls Faced': '1',
#     'Fours': '0',
#     'Sixes': '0',
#     'Strike Rate': '0.00'}],
#   'Extras': 'Extras (w 3, lb 2)',
#   'balling': [{'player_name': 'Pramod Madushan',
#     'Overs': '2',
#     'Maidens': '0',
#     'Runs': '21',
#     'Wickets': '0',
#     'Economy': '10.50',
#     'Dots': '5'},
#    {'player_name': 'Matheesha Pathirana',
#     'Overs': '2',
#     'Maidens': '0',
#     'Runs': '21',
#     'Wickets': '0',
#     'Economy': '10.50',
#     'Dots': '5'},
#    {'player_name': 'Dunith Wellalage',
#     'Overs': '2',
#     'Maidens': '0',
#     'Runs': '7',
#     'Wickets': '0',
#     'Economy': '3.50',
#     'Dots': '8'},
#    {'player_name': 'Charith Asalanka',
#     'Overs': '0.1',
#     'Maidens': '0',
#     'Runs': '1',
#     'Wickets': '0',
#     'Economy': '6.00',
#     'Dots': '0'}]},
#  'match_id': '102846'}
